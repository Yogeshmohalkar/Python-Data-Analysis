# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
df = pd.read_csv("Salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head(78)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.rank()
# Out:
#     rank  discipline   phd  service   sex  salary
# 0   55.5        57.5  78.0     77.0  59.0    78.0
# 1   55.5        18.5  25.0     22.0  59.0    29.0
# 2   55.5        18.5  50.5     57.0  59.0    48.0
# 3   55.5        18.5  74.0     70.5  59.0    63.0
# 4   55.5        57.5  44.0     47.0  59.0    40.0
# ..   ...         ...   ...      ...   ...     ...
# 73  55.5        57.5  37.5     34.0  20.0    42.0
# 74   7.0        57.5  40.5     22.0  20.0    39.0
# 75  55.5        57.5  33.0     43.0  20.0    57.0
# 76  55.5        18.5  60.0     38.5  20.0    47.0
# 77  55.5        18.5  50.5     40.5  20.0    45.0
#
# [78 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean( ' ' )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     512         try:
# --> 513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
#
# KeyError: ' '
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-234-121f56daa582> in <cell line: 1>()
# ----> 1 df.mean( ' ' )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# ...

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.quantile(0.25)
# Out:
# 10.25

# %%
df.phd.quantile(0.50)

# %%
df.phd.quantile(0.75)

# %%
df.std()

# %%
df_50 = df.head(50)

# %%
df_50

# %%
df_50.phd.mean()

# %%
df_50.mean()

# %%
df.head(50).mean()

# %%
df.phd.head(50).mean()

# %%
df.salary

# %%
df['salary']

# %%
result1 = df.salary

# %%
result1

# %%
result1.describe()

# %%
type(result1)

# %%
result2 = df[['salary','rank']]
result2

# %%
type(result2)

# %%
newdf = df[['salary','rank','phd']]

newdf

# %%
type(newdf)

# %%
df['discipline'].value_counts()

# %%
df['rank'].value_counts()

# %%
df['salary'].head(5).value_counts()

# %%
df['rank'].head(5).value_counts()

# %%
df['phd'].value_counts()

# %% [markdown]
# ## BASIC STATSITCS OF PHD COLUMN

# %%
df.phd.describe()

# %%
df.phd.count()
# Out:
# 78

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
 df.groupby(['rank']).mean(' ')
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df.groupby(['rank']).value_counts()
# Out:
# rank       discipline  phd  service  sex     salary
# AssocProf  A           10   8        Female  77500     1
#                        13   8        Female  74830     1
#            B           13   10       Female  103750    1
#                        19   6        Female  104542    1
#                        14   7        Female  109650    1
#                                                       ..
# Prof       A           18   18       Male    126300    1
#                        17   11       Female  90450     1
#                        12   6        Male    93000     1
#                             0        Female  105000    1
#            B           56   49       Male    186960    1
# Name: count, Length: 78, dtype: int64

# %%
newdf.groupby(['rank']).value_counts().mean()
# Out:
# 1.0129870129870129

# %%
groupdf = df[['phd','service','salary','rank']]

# %%
groupdf
# Out:
#     phd  service  salary       rank
# 0    56       49  186960       Prof
# 1    12        6   93000       Prof
# 2    23       20  110515       Prof
# 3    40       31  131205       Prof
# 4    20       18  104800       Prof
# ..  ...      ...     ...        ...
# 73   18       10  105450       Prof
# 74   19        6  104542  AssocProf
# 75   17       17  124312       Prof
# 76   28       14  109954       Prof
# 77   23       15  109646       Prof
#
# [78 rows x 4 columns]

# %%
groupdf.groupby(['rank']).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.groupby(['rank']).mean(' ')
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['rank']).count()
# Out:
#            discipline  phd  service  sex  salary
# rank
# AssocProf          13   13       13   13      13
# AsstProf           19   19       19   19      19
# Prof               46   46       46   46      46

# %%
df.groupby(['sex']).mean(' ')
# Out:
#               phd    service         salary
# sex
# Female  16.512821  11.564103  101002.410256
# Male    22.897436  18.538462  115045.153846

# %%
df.groupby(['sex']).count()
# Out:
#         rank  discipline  phd  service  salary
# sex
# Female    39          39   39       39      39
# Male      39          39   39       39      39

# %%
df.groupby(['sex']).value_counts()
# Out:
# sex     rank       discipline  phd  service  salary
# Female  AssocProf  A           10   8        77500     1
#                                13   8        74830     1
#         Prof       B           36   26       144651    1
#         AsstProf   A           2    0        72500     1
#                    B           4    2        80225     1
#                                                       ..
# Male    Prof       A           40   31       131205    1
#                                38   19       148750    1
#         AssocProf  B           9    7        107008    1
#                    A           20   17       81285     1
#         Prof       B           56   49       186960    1
# Name: count, Length: 78, dtype: int64

# %%
df.groupby(['discipline']).count()
# Out:
#             rank  phd  service  sex  salary
# discipline
# A             36   36       36   36      36
# B             42   42       42   42      42

# %%
df.groupby(['discipline','rank']).count()
# Out:
#                       phd  service  sex  salary
# discipline rank
# A          AssocProf    5        5    5       5
#            AsstProf     8        8    8       8
#            Prof        23       23   23      23
# B          AssocProf    8        8    8       8
#            AsstProf    11       11   11      11
#            Prof        23       23   23      23

# %%
df.groupby(['discipline','rank','sex']).count()
# Out:
#                              phd  service  salary
# discipline rank      sex
# A          AssocProf Female    4        4       4
#                      Male      1        1       1
#            AsstProf  Female    6        6       6
#                      Male      2        2       2
#            Prof      Female    8        8       8
#                      Male     15       15      15
# B          AssocProf Female    6        6       6
#                      Male      2        2       2
#            AsstProf  Female    5        5       5
#                      Male      6        6       6
#            Prof      Female   10       10      10
#                      Male     13       13      13

# %%
df.groupby(['discipline','rank','sex']).mean()
# Out:
#                                    phd    service         salary
# discipline rank      sex
# A          AssocProf Female  18.500000  15.500000   72128.500000
#                      Male    20.000000  17.000000   81285.000000
#            AsstProf  Female   4.833333   2.500000   72933.333333
#                      Male     3.000000   1.000000   79000.000000
#            Prof      Female  26.500000  16.125000  109631.875000
#                      Male    28.933333  22.733333  113164.400000
# B          AssocProf Female  13.500000   8.833333   99435.666667
#                      Male    10.500000   7.500000  113404.000000
#            AsstProf  Female   6.600000   2.600000   84189.800000
#                      Male     4.666667   2.000000   88224.000000
#            Prof      Female  21.500000  17.900000  131836.200000
#                      Male    29.538462  25.846154  137989.076923

# %%
df.groupby(['discipline','rank']).mean(' ') # NEED TO USE QUOTATION MARK TO GET MEAN
# Out:
#                             phd    service         salary
# discipline rank
# A          AssocProf  18.800000  15.800000   73959.800000
#            AsstProf    4.375000   2.125000   74450.000000
#            Prof       28.086957  20.434783  111935.695652
# B          AssocProf  12.750000   8.500000  102927.750000
#            AsstProf    5.545455   2.272727   86390.272727
#            Prof       26.043478  22.391304  135313.913043

# %%
df.groupby(['salary'])

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
grouped = df.groupby('rank')

# %%
grouped

# %%
for g in grouped:
 print(g)
# Out:
# ('AssocProf',          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 64  AssocProf          A   26       24  Female   73300
# 71  AssocProf          B   12        9  Female   71065
# 74  AssocProf          B   19        6  Female  104542)
# ('AsstProf',         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 16  AsstProf          B    8        3    Male   75044
# ...

# %%
 df[df.salary > 120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df.shape
# Out:
# (78, 6)

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %%
df[df.salary > 120000].shape[0]
# Out:
# 25

# %%
df[df.salary > 120000].count()
# Out:
# rank          25
# discipline    25
# phd           25
# service       25
# sex           25
# salary        25
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
newdf = df[ (df['sex'] == 'Male') & ( df['salary'] > 150000 ) ]

# %%
newdf
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
newdf.count()
# Out:
# rank          7
# discipline    7
# phd           7
# service       7
# sex           7
# salary        7
# dtype: int64

# %%
newdf.value_counts()
# Out:
# rank  discipline  phd  service  sex   salary
# Prof  A           29   27       Male  150500    1
#                   45   43       Male  155865    1
#       B           17   3        Male  150480    1
#                   22   21       Male  155750    1
#                   25   19       Male  153750    1
#                   35   33       Male  162200    1
#                   56   49       Male  186960    1
# Name: count, dtype: int64

# %%
newdf.shape[0]
# Out:
# 7

# %%
df[ df['rank'] != 'Prof' ].shape[0]
# Out:
# 32

# %%
df[(df['service'] > 15) | (df['salary'] > 100000)]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# ...

# %%
df[(df['service'] > 15) | (df['salary'] > 100000)].shape[0]
# Out:
# 54

# %%
df[(df['service'] > 15) | (df['salary'] > 100000)].shape
# Out:
# (54, 6)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df[5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.iloc[5]
# Out:
# rank            Prof
# discipline         A
# phd               20
# service           20
# sex             Male
# salary        122400
# Name: 5, dtype: object

# %%
df.iloc[77]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[1:4, 0:3]
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40

# %%
df.iloc[5:17, 2:5]
# Out:
#     phd  service   sex
# 5    20       20  Male
# 6    20       17  Male
# 7    18       18  Male
# 8    29       19  Male
# 9    51       51  Male
# 10   39       33  Male
# 11   23       23  Male
# 12    1        0  Male
# 13   35       33  Male
# 14   25       19  Male
# 15   17        3  Male
# 16    8        3  Male

# %%
df.iloc[1:4, ]
# Out:
#    rank discipline  phd  service   sex  salary
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
df.iloc[:,4 ] # ALL THE  ROWS & 4TH COLUMN
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
df.iloc[:,0:5 ]
# Out:
#          rank discipline  phd  service     sex
# 0        Prof          B   56       49    Male
# 1        Prof          A   12        6    Male
# 2        Prof          A   23       20    Male
# 3        Prof          A   40       31    Male
# 4        Prof          B   20       18    Male
# ..        ...        ...  ...      ...     ...
# 73       Prof          B   18       10  Female
# 74  AssocProf          B   19        6  Female
# 75       Prof          B   17       17  Female
# 76       Prof          A   28       14  Female
# 77       Prof          A   23       15  Female
#
# [78 rows x 5 columns]

# %%
df.iloc[[2,44,55,20,45] , ]
# Out:
#         rank discipline  phd  service     sex  salary
# 2       Prof          A   23       20    Male  110515
# 44      Prof          B   23       19  Female  151768
# 55  AsstProf          A    2        0  Female   72500
# 20  AsstProf          B    4        4    Male   92000
# 45      Prof          B   25       25  Female  140096

# %%
df.loc[: , ['rank','sex']]
# Out:
#          rank     sex
# 0        Prof    Male
# 1        Prof    Male
# 2        Prof    Male
# 3        Prof    Male
# 4        Prof    Male
# ..        ...     ...
# 73       Prof  Female
# 74  AssocProf  Female
# 75       Prof  Female
# 76       Prof  Female
# 77       Prof  Female
#
# [78 rows x 2 columns]

# %%
df.loc[[1,2,3,4,5],['rank','discipline','sex']]
# Out:
#    rank discipline   sex
# 1  Prof          A  Male
# 2  Prof          A  Male
# 3  Prof          A  Male
# 4  Prof          B  Male
# 5  Prof          A  Male

# %%
df.iloc[::5]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 5        Prof          A   20       20    Male  122400
# 10       Prof          B   39       33    Male  128250
# 15       Prof          B   17        3    Male  150480
# 20   AsstProf          B    4        4    Male   92000
# 25       Prof          B   35       31    Male   99418
# 30  AssocProf          B    9        7    Male  107008
# 35       Prof          B   28       23    Male  126933
# 40       Prof          A   39       36  Female  137000
# 45       Prof          B   25       25  Female  140096
# 50   AsstProf          B   10        5  Female   97032
# 55   AsstProf          A    2        0  Female   72500
# 60   AsstProf          B    3        3  Female   92000
# 65       Prof          A   36       19  Female  117555
# 70   AsstProf          A    8        3  Female   78500
# 75       Prof          B   17       17  Female  124312

# %%
df.iloc[10:30:4]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 14      Prof          B   25       19  Male  153750
# 18      Prof          A   19        7  Male  107300
# 22  AsstProf          A    4        2  Male   73000
# 26      Prof          A   38       19  Male  148750

# %%
df.iloc[::-1]
# Out:
#          rank discipline  phd  service     sex  salary
# 77       Prof          A   23       15  Female  109646
# 76       Prof          A   28       14  Female  109954
# 75       Prof          B   17       17  Female  124312
# 74  AssocProf          B   19        6  Female  104542
# 73       Prof          B   18       10  Female  105450
# ..        ...        ...  ...      ...     ...     ...
# 4        Prof          B   20       18    Male  104800
# 3        Prof          A   40       31    Male  131205
# 2        Prof          A   23       20    Male  110515
# 1        Prof          A   12        6    Male   93000
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
df[['phd','salary']].agg(['min','mean','max','std']) # mad(Mean Absolute Deviation) function is not working
# Out:
#             phd         salary
# min    1.000000   57800.000000
# mean  19.705128  108023.782051
# max   56.000000  186960.000000
# std   12.498425   28293.661022

# %%
df[['salary']].agg('skew')
# Out:
# salary    0.452103
# dtype: float64

# %%
df[['salary']].agg('kurt')
# Out:
# salary   -0.401713
# dtype: float64

# %%
df.var() # this function not working
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      95                 with np.errstate(invalid="ignore"):
# ---> 96                     return f(*args, **kwargs)
#      97             except ValueError as e:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     157             else:
# --> 158                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     159
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanvar(values, axis, skipna, ddof, mask)
#    1003     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1004     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1005     if axis is not None:
#
# ...

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.sem
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sem of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>
